# %%
import os

# %%
os.path.isdir("/Users/Gregg/Dropbox (MIT)/2021 Gregg Sur rotation/ASC_experimental_data/2022-11 Soma Data/ASC26 cell 3.mat")
# Out:
# False

# %%
test_dict = {}
test_2 = test_dict

# %%
test_2['o'] = 0

# %%
print(test_dict)
# Out:
# {'o': 0}

# %%
data_path = "/Users/Gregg/Dropbox (MIT)/2021 Gregg Sur rotation/ASC_experimental_data/2022-11 Soma Data/ASC26 cell 3.mat"#r"/Users/Gregg/Dropbox (MIT)/2021 Gregg rotation/kyle_data"

# %%
data_path.replace('Soma', 'Spine')
# Out:
# '/Users/Gregg/Dropbox (MIT)/2021 Gregg Sur rotation/ASC_experimental_data/2022-11 Spine Data/ASC26 cell 3.mat'

# %%
test_data = [0,1,2,3,2,1,0,1,2,1]

# %%
len(test_data)
# Out:
# 10

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.plot(test_data)
ax.set_xticks([0,3,6,8], ['Orthogonal', 'Preferred', 'Orthogonal', 'Anit-preferred'])
ax.scatter(1,2,marker='*')

# %%
locs, labels = ax.xticks()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 locs, labels = ax.xticks()
#
# AttributeError: 'AxesSubplot' object has no attribute 'xticks'

# %%
import src.plotting as plot

# %%
plot.plot_tuning_curves(test_data = [0,1,2,3,2,1,0,1,2,1])
# Out:
# test_data
# [0 1 2 3 2 1 0 1 2 1]

# %%
from scipy import stats

# %%
a = stats.pearsonr([1,2,3],[1,2,3])

# %%
a[0]
# Out:
# 0.9999999999999998

# %%
a
# Out:
# PearsonRResult(statistic=0.9999999999999998, pvalue=1.3415758552508151e-08)
